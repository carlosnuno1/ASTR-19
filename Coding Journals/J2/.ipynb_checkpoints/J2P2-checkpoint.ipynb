# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 1, 100)

# %%
def Sin(x):
    return np.sin(x)

# %%
def Cos(x):
    return np.cos(x)

# %%
plt.subplot(1,2,1)
plt.plot(Sin(x), x)
plt.title('Sin(x)')
plt.xlabel('x-axis')
plt.ylabel('y-axis')

plt.subplot(1,2,2)
plt.plot(Cos(x), x)
plt.title('Cos(x)')
plt.xlabel('x-axis')
plt.ylabel('y-axis')

plt.tight_layout()
plt.savefig("J2P2plot.pdf")
