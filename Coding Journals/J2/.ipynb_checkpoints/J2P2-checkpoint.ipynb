# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 1, 100)

# %%
def Sin(x):
    return np.sin(x)

# %%
def Cos(x):
    return np.cos(x)

# %%
plt.subplot(1,2,1)
plt.plot(Sin(x), x)
plt.title('sine')
plt.xlabel('xaxis')
plt.ylabel('yaxis')

plt.subplot(1,2,2)
plt.plot(Cos(x), x)
plt.title('cosine')
plt.xlabel('xaxis')
plt.ylabel('yaxis')
plt.show()
