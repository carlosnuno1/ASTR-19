# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(0, 1, 100)

# %%
def Exp(x):
    return np.exp(x)

# %%
y = Exp(x)

# %%
plt.plot(x,y)
plt.xlabel('Time [milliseconds]')
plt.ylabel('Awesomeness')
plt.savefig("J2P1plot.pdf")
